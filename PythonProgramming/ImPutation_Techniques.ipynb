# %%
import pandas as pd
df=pd.read_csv("/content/drive/MyDrive/Colab Notebooks/malefemale - source data.csv")

threshold = 80
null_percentages = (df.isnull().sum() / len(df)) * 100
print(null_percentages)
print("hii")
columns_to_remove = null_percentages[null_percentages > threshold].index
df_cleaned = df.drop(columns=columns_to_remove)
a=df_cleaned
nll_percentages = (df_cleaned.isnull().sum() / len(df_cleaned)) * 100
print(nll_percentages)
print("hello")
back=df_cleaned.bfill(axis =0)
c=back
c
print("-----back---")
back_f=(c.isnull().sum() / len(c)) * 100
print(back_f)
f=df_cleaned.ffill(axis =0)
print("farward filling")



print("-----foward---")
f_percentages = (f.isnull().sum() / len(f)) * 100
print(f_percentages)
d=f
d
# Out:
# gender                  0.000000
# age                     0.000000
# Investment_Avenues      0.000000
# Mutual_Funds           10.526316
# Equity_Market           5.263158
# Debentures              5.263158
# Government_Bonds      100.000000
# Fixed_Deposits         42.105263
# PPF                    73.684211
# Gold                  100.000000
# dtype: float64
# hii
# gender                 0.000000
# age                    0.000000
# Investment_Avenues     0.000000
# Mutual_Funds          10.526316
# Equity_Market          5.263158
# Debentures             5.263158
# Fixed_Deposits        42.105263
# PPF                   73.684211
# dtype: float64
# hello
# -----back---
# gender                 0.000000
# age                    0.000000
# Investment_Avenues     0.000000
# Mutual_Funds           0.000000
# Equity_Market          0.000000
# Debentures             0.000000
# Fixed_Deposits         0.000000
# PPF                   73.684211
# dtype: float64
# farward filling
# ...
